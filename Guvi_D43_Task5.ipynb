# %% [markdown]
# <a href="https://colab.research.google.com/github/SSathyaprakash/Guvi-Task-5/blob/main/Guvi_D43_Task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pty

# %%
x=pd.read_csv("/content/drive/MyDrive/my_drive/Task5/takehome_user_engagement.csv",encoding='ISO-8859-1')
y=pd.read_csv("/content/drive/MyDrive/my_drive/Task5/takehome_users.csv",encoding='ISO-8859-1')

df_user_eng=pd.DataFrame(x)

df_user=pd.DataFrame(y)
df_user = df_user.fillna(0)
df_user1 = df_user_eng.fillna(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207917 entries, 0 to 207916
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time_stamp  207917 non-null  object
#  1   user_id     207917 non-null  int64
#  2   visited     207917 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.8+ MB

# %% [markdown]
# what is creation sourse ratio?

# %%
df_p1=pd.pivot_table(df_user,index='creation_source',values=['name','opted_in_to_mailing_list','enabled_for_marketing_drip'],aggfunc={'name':'count','opted_in_to_mailing_list' :np.sum,'enabled_for_marketing_drip':np.sum})



print(df_p1)
df_p1.plot(kind='bar')
pty.title("creation_source comparation")
# Out:
#                     enabled_for_marketing_drip  name  opted_in_to_mailing_list
# creation_source
# GUEST_INVITE                               319  2163                       541
# ORG_INVITE                                 644  4254                      1078
# PERSONAL_PROJECTS                          303  2111                       512
# SIGNUP                                     319  2087                       525
# SIGNUP_GOOGLE_AUTH                         207  1385                       338
# Text(0.5, 1.0, 'creation_source comparation')

# %%
pie=df_p1["name"].plot(kind='pie')

# %%
df_p1['creation_source %'] = (df_p1.name / df_p1.name.sum() * 100)
df_p1['enabled_for_marketing_drip %'] = (df_p1.enabled_for_marketing_drip / df_p1.enabled_for_marketing_drip.sum() * 100)
df_p1['opted_in_to_mailing_list %'] = (df_p1.opted_in_to_mailing_list / df_p1.opted_in_to_mailing_list.sum() * 100)
x=(df_p1[["creation_source %","enabled_for_marketing_drip %","opted_in_to_mailing_list %"]])
x.plot(kind='bar')
pty.title("creation_source comparation ratio")
# Out:
# Text(0.5, 1.0, 'creation_source comparation ratio')

# %% [markdown]
# what is creation sourse ratio?

# %% [markdown]
# as We see in numbers and in ratio comparation of creation source and peoplw who opted for mail and markating are high in point of **Organation invites**

# %% [markdown]
# # what organization has the most users?
# # ANSWER: most users belong to organization id: 1 -> 10 except 8

# %%
df_user.org_id.value_counts().head(10)
# Out:
# 0     319
# 1     233
# 2     201
# 3     168
# 4     159
# 6     138
# 5     128
# 9     124
# 7     119
# 10    104
# Name: org_id, dtype: int64
